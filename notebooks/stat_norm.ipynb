# %%
# !pip install plotly
import sys
sys.path.insert(0, "..")
from config_path import datasets, dataset_paths, dataset_full_name
from stat_norm import get_dataset_stats, plot_stats, convert, launch_rescale, compare_stat_norm

# %% [markdown]
# ## Compute object statistics

# %%
stats = {d: get_dataset_stats(dataset_paths[d]) for d in datasets}

# %%
plot_stats(stats)

# %% [markdown]
# ## Generate rescaled datasets

# %%
launch_rescale()

# %%
compare_stat_norm(src="kitti", dst="nusc", dataid=10)
